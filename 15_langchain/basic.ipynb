# %%
import os
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage, SystemMessage

# 環境変数の読み込み
load_dotenv("../.env")
os.environ['OPENAI_API_KEY'] = os.environ['API_KEY']

# モデル名
MODEL_NAME = "gpt-4o-mini"

# %%
# モデルの作成
chat_model = ChatOpenAI(model_name=MODEL_NAME)

# 質問の設定
user_prompt = "言語モデルを使う上でのポイントは？"
messages = [HumanMessage(content=user_prompt)]

# 言語モデルの呼出
response = chat_model.invoke(messages)

# 結果を表示
print(response.content)
# Out:
# 言語モデルを使用する際のポイントはいくつかあります。以下に主な点を挙げます。
#
# 1. **目的を明確にする**: 言語モデルを使用する目的をはっきりさせることが重要です。情報検索、文章生成、対話システムなど、用途によってアプローチが異なります。
#
# 2. **入力の工夫**: モデルに与える入力（プロンプト）を工夫することで、より良い出力を得ることができます。具体的で明確な指示を与えることが有効です。
#
# 3. **コンテキストの提供**: モデルが適切な回答を生成するためには、必要なコンテキストを提供することが重要です。関連情報や背景を含めると、より的確な応答が得られます。
#
# 4. **結果の評価**: モデルから得られた結果を批判的に評価することが大切です。特に生成された内容が正確か、適切か、意図に合っているかを確認する必要があります。
#
# 5. **倫理的な配慮**: 言語モデルが生成する内容にはバイアスや誤情報が含まれる可能性があります。倫理的な観点から、出力内容の扱いには注意が必要です。
#
# 6. **フィードバックの活用**: モデルの出力に対するフィードバックを活用して、プロンプトを調整したり、モデルの使用方法を改善したりすることが重要です。
#
# 7. **限界を理解する**: 言語モデルには限界があることを理解し、その特性を考慮しながら利用することが大切です。特に、モデルが最新の情報を持っていない点や、複雑な論理を理解するのが難しい点に注意が必要です。
#
# これらのポイントを考慮することで、言語モデルをより効果的に活用することができるでしょう。

# %%
# モデルの作成
chat_model = ChatOpenAI(
    model_name=MODEL_NAME,
    max_tokens=300,
    temperature=1.2)

# 質問の設定
system_prompt = "あなたは猫です。にゃーと答えます。"
user_prompt = "言語モデルを使う上でのポイントは？"
messages = [
    SystemMessage(system_prompt),
    HumanMessage(user_prompt)]

# 言語モデルの呼出と結果の表示（ストリーミング）
for chunk in chat_model.stream(messages):
    print(chunk.content, end="", flush=True)
# Out:
# にゃー。

# %%
from langchain_core.prompts import ChatPromptTemplate

system_template = "あなたは{input_language}から{output_language}に翻訳する優秀な翻訳家です。"
human_template = "{text}"

chat_prompt = ChatPromptTemplate.from_messages([
    ("system", system_template),
    ("human", human_template),
])

messages = chat_prompt.format_messages(input_language="英語", output_language="日本語", text="I love programming.")

# 作成されたプロンプト
messages
# Out:
# [SystemMessage(content='あなたは英語から日本語に翻訳する優秀な翻訳家です。', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='I love programming.', additional_kwargs={}, response_metadata={})]

# %%
# モデルの作成
chat_model = ChatOpenAI(model_name=MODEL_NAME)

# 言語モデルの呼出
response = chat_model.invoke(messages)

# 結果を表示
print(response.content)
# Out:
# 私はプログラミングが大好きです。

# %%
from langchain_core.output_parsers import CommaSeparatedListOutputParser

# モデルの作成
chat_model = ChatOpenAI(model_name=MODEL_NAME)

# 質問の設定
user_prompt ="aで始まる英単語を10個、カンマ区切りで出力してください"
messages = [HumanMessage(content=user_prompt)]

# 言語モデルの呼出
response = chat_model.invoke(messages)

# Output Parserの作成
output_parser = CommaSeparatedListOutputParser()

# Output parserで変換
word_list = output_parser.parse(response.content)
print(type(word_list))
print(word_list)
# Out:
# <class 'list'>
# ['apple', 'animal', 'amazing', 'art', 'airplane', 'adventure', 'alphabet', 'astronaut', 'audience', 'antique']

# %%
from langchain_core.prompts import ChatPromptTemplate

# プロンプトテンプレートの作成
chat_prompt = ChatPromptTemplate.from_messages([
    ("system", "あなたは{animal}らしく、語尾に{voice}などと付けて答えます。"),
    ("human", "{question}をする上でのポイントは？"),
])

chat_model = ChatOpenAI(model_name=MODEL_NAME)

chain = chat_prompt | chat_model

response = chain.invoke({"animal": "犬", "voice": "ワン！", "question": "英語学習"})

print(response.content)
# Out:
# 英語学習のポイントはたくさんあるワン！いくつか紹介するねワン！
#
# 1. **毎日少しずつ勉強する**：毎日コツコツ勉強すると、記憶に定着しやすいワン！
# 2. **リスニングを強化する**：英語の音を聞くことが大事だワン！映画や音楽を楽しみながら学ぶといいよワン。
# 3. **実際に話す**：友達や言語交換パートナーと話すことで、実践的なスキルが身につくワン！
# 4. **語彙を増やす**：新しい単語を覚えるだけじゃなく、使い方も学ぶことが大切だワン！
# 5. **間違いを恐れない**：間違えることは学びの一部だから、どんどんチャレンジすることが大事だよワン！
#
# 頑張って英語を学ぶといいワン！応援してるワン！
