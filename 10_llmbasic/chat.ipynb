# %%
import os
from dotenv import load_dotenv
from openai import OpenAI
from pprint import pprint

# 環境変数の取得
load_dotenv("../.env")

# OpenAI APIクライアントを生成
client = OpenAI(api_key=os.environ['API_KEY'])

# モデル名
MODEL_NAME = "gpt-4o-mini"

# %%
# メッセージの設定
message = "言語モデルを使う上でのポイントは"

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ]
)

# レスポンスの表示
pprint(vars(response))
# Out:
# {'_request_id': 'req_6876208b048647328713106a73578a7a',
#  'choices': [Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='言語モデルを効果的に使うためのポイントはいくつかあります。以下にいくつかの重要な点を挙げます。\n\n1. **明確な問いを立てる**: モデルに質問やリクエストをする際には、できるだけ具体的で明確な言葉を使うと、より良い回答が得られます。\n\n2. **文脈の提供**: 情報が必要なテーマや状況についての文脈を提供することで、モデルはより関連性のある回答を生成しやすくなります。\n\n3. **フィードバックを活用する**: 得られた回答が期待したものでない場合、再度質問し直す、または追加の情報を提供することで、より良い結果を得ることができます。\n\n4. **使い方の多様性**: 言語モデルは情報検索だけでなく、アイデアのブレインストーミング、文章の校正、プログラムのコード作成など、さまざまな用途に使用できます。\n\n5. **限界を理解する**: モデルは訓練データに基づいて回答を生成するため、最新の情報や専門的な知識に関しては必ずしも正確でない場合があります。信頼できる情報が必要な際は、他の情報源を確認することも重要です。\n\n6. **倫理的考慮**: モデルの使用に際しては、プライバシーやデータの取り扱いに注意し、倫理的に適切な方法で利用することが大切です。\n\n7. **エクスペリメンテーション**: モデルの応答スタイルやトーンを調整するために、さまざまなアプローチを試すことで、より満足のいく結果を得ることができます。\n\nこれらのポイントを意識することで、言語モデルをより効果的に活用し、有益な結果を得ることができるでしょう。', refusal=None, role='assistant', audio=None, function_call=None, tool_calls=None, annotations=[]))],
#  'created': 1771306596,
#  'id': 'chatcmpl-DA83A3RsALV0eV5tiV1yHm5dnw0OV',
#  'model': 'gpt-4o-mini-2024-07-18',
#  'object': 'chat.completion',
#  'service_tier': 'default',
#  'system_fingerprint': 'fp_373a14eb6f',
#  'usage': CompletionUsage(completion_tokens=465, prompt_tokens=18, total_tokens=483, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))}

# %%
# 言語モデルからの回答を表示
print(response.choices[0].message.content.strip())
# Out:
# 言語モデルを効果的に使うためのポイントはいくつかあります。以下にいくつかの重要な点を挙げます。
#
# 1. **明確な問いを立てる**: モデルに質問やリクエストをする際には、できるだけ具体的で明確な言葉を使うと、より良い回答が得られます。
#
# 2. **文脈の提供**: 情報が必要なテーマや状況についての文脈を提供することで、モデルはより関連性のある回答を生成しやすくなります。
#
# 3. **フィードバックを活用する**: 得られた回答が期待したものでない場合、再度質問し直す、または追加の情報を提供することで、より良い結果を得ることができます。
#
# 4. **使い方の多様性**: 言語モデルは情報検索だけでなく、アイデアのブレインストーミング、文章の校正、プログラムのコード作成など、さまざまな用途に使用できます。
#
# 5. **限界を理解する**: モデルは訓練データに基づいて回答を生成するため、最新の情報や専門的な知識に関しては必ずしも正確でない場合があります。信頼できる情報が必要な際は、他の情報源を確認することも重要です。
#
# 6. **倫理的考慮**: モデルの使用に際しては、プライバシーやデータの取り扱いに注意し、倫理的に適切な方法で利用することが大切です。
#
# 7. **エクスペリメンテーション**: モデルの応答スタイルやトーンを調整するために、さまざまなアプローチを試すことで、より満足のいく結果を得ることができます。
#
# これらのポイントを意識することで、言語モデルをより効果的に活用し、有益な結果を得ることができるでしょう。

# %%
# 役割や前提の設定
role = "あなたはマーケティング分野に精通したビジネスコンサルタントです。企業の成長をサポートするために、効果的なマーケティング戦略を提供します。"

# メッセージの設定
message = "新製品の発売に向けた効果的なマーケティング戦略を教えてください。"

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "system", "content": role},
        {"role": "user", "content": message},
    ],
)

# 言語モデルからの回答を表示
print(response.choices[0].message.content.strip())
# Out:
# 新製品の発売に向けた効果的なマーケティング戦略には、いくつかの重要なステップがあります。以下に詳細をまとめました。
#
# ### 1. 市場調査
# - **ターゲット市場の特定**: 新製品がどのような顧客層に最も適しているかを分析します。
# - **競合分析**: 同様の製品を扱っている競合他社を調べ、彼らの強みと弱みを理解します。
# - **顧客ニーズの把握**: 調査やインタビューを通じて、顧客が直面している課題やニーズを明確にします。
#
# ### 2. 製品ポジショニング
# - **ユニークなセリングポイント (USP) の明確化**: 新製品が競合製品と比べて何が優れているのか、明確なメリットを定義します。
# - **ブランドメッセージの策定**: ブランドの価値や新製品の特長を効果的に伝えるためのメッセージを作成します。
#
# ### 3. マーケティングチャネルの選定
# - **オンラインとオフラインの統合**: ソーシャルメディア、メールマーケティング、広告、イベントなど、経路を多様化して、ターゲットにリーチします。
# - **インフルエンサーとのコラボレーション**: ターゲット市場に影響を与えるインフルエンサーと連携し、製品のプレゼンテーションを行います。
#
# ### 4. プロモーション計画
# - **ティーザーキャンペーン**: 発売前から話題を作るために、製品情報の一部をクローズドに公開することを行います。
# - **プレローンチイベント**: 関係者やジャーナリストを招待し、試用機会を提供することで注目を集めます。
# - **ローンチ日までのカウントダウン**: ソーシャルメディアやウェブサイトを通じてカウントダウンを行い、期待感を高めます。
#
# ### 5. 発売日
# - **製品の正式発表**: 発売日に公式に製品を発表し、増進した関心を引き込みます。
# - **特別オファーや割引**: 初期購入者向けにディスカウントや特典を用意し、購入を促進します。
#
# ### 6. フィードバックと改善
# - **顧客の声を聞く**: 発売後には顧客のフィードバックを集め、製品の改善点や新しいニーズを把握します。
# - **データ分析**: 販売データやマーケティングデータをもとに、戦略の見直しや調整を行います。
#
# ### 7. ロングターム戦略
# - **リピート購入促進**: 新製品の購入者に対して、アフターサービスや関連製品の提案を行い、リピート購入を促します。
# - **顧客ロイヤリティプログラム**: 長期的な関係構築を促進するために、ロイヤリティプログラムを導入します。
#
# これらのステップを組み合わせることで、新製品の効果的なマーケティング戦略が構築でき、ターゲット市場において成功する可能性を高めることができます。

# %%
# 出力の多様性
message = "日本の魅力を紹介して！"

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ],
    temperature=1.4,
    n = 3, # 3回答を得る
    max_completion_tokens = 100 # 出力トークン長を制限
)

# 結果を表示（複数回答を比較）
for choice in response.choices:
    print("-" * 20)
    print(choice.message.content.strip())
# Out:
# --------------------
# もちろんです！日本には多くの魅力がありますので、いくつかのポイントを紹介します。
#
# ### 1. 自然の美しさ
# 日本は四季が明確で、それぞれの季節に独自の美しさがあります。桜が咲く春や、紅葉の美しい秋など、季節ごとに訪れる景色が楽しめます。また、日本各地には美しい山々や海、温
# --------------------
# もちろんです！日本には多くの魅力があります。
#
# 1. **文化と伝統**: 日本は、古い神社やお寺、伝統的な祭り、茶道、武道など、豊かな伝統文化が息づいています。特に京都には、美しい神社や古都の風情があります。
#
# 2. **美味しい食文化**: 日本の食は、寿司、ラーメン、天ぷら、
# --------------------
# もちろんです！日本は、文化、自然、食、美術、歴史が見事に融合した国で、さまざまな魅力があります。以下にいくつかのポイントを紹介します。
#
# ### 1. 文化と伝統
# - **お祭り**: 日本各地ではさまざまなお祭りがあり、地元の風情や伝統が感じられます。例えば、京都の祇園祭や

# %%
# 出力の多様性
message = "日本の魅力を紹介して！"

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ],
    presence_penalty=-2.0,
    n = 3, # 3回答を得る
    max_completion_tokens = 100 # 出力トークン長を制限
)

# 結果を表示（複数回答を比較）
for choice in response.choices:
    print("-" * 20)
    print(choice.message.content.strip())
# Out:
# --------------------
# もちろんです！日本には多くの魅力があり、文化、自然、食、歴史など多様な面が楽しめます。以下にいくつかのポイントを紹介します。
#
# ### 1. 文化と伝統
# - **伝統的な祭り**: 日本には四季折々の祭りがあり、例えば、春にはさくら祭り、夏には花火大会や盆踊り、秋には秋祭り
# --------------------
# もちろんです！日本にはたくさんの魅力があります。以下はいくつかのポイントです。
#
# ### 1. 文化と伝統
# 日本は古くからの伝統文化が息づく国です。茶道、華道、武道、祭りなど、さまざまな伝統が今も大切にされています。また、歌舞伎や能、浮世絵などの伝統芸術も魅力的です。
# --------------------
# もちろんです！日本の魅力はたくさんありますが、いくつかのポイントを挙げてみます。
#
# 1. **豊かな自然**: 日本は四季がはっきりしており、春の桜、夏の緑、秋の紅葉、冬の雪景色が楽しめます。特に、富士山や多くの温泉地は自然の美しさを堪能できる場所

# %%
import tiktoken
from tiktoken.core import Encoding

# OpenAI APIの特定のモデルに対応するトークナイザーを取得
encoding: Encoding = tiktoken.encoding_for_model(MODEL_NAME) # o200k_base

# テキストをトークンIDのリストに変換
tokens = encoding.encode("こんにちは！")
tokens_count = len(tokens)

# トークンの長さとトークンIDを表示
print(f"{tokens_count=}")
print(f"{tokens=}")
# Out:
# tokens_count=2
# tokens=[95839, 3393]

# %%
# トークンの選択度合い
message = """
AさんとBさんで会話してください。
A:あ、Bさんだ。
B:
"""

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ],
    max_tokens=100,
    n=3,
    logit_bias = {95839:8, 3393:8}
)

# 結果を表示
for choice in response.choices:
    print("-" * 20)
    print(choice.message.content.strip())
# Out:
# --------------------
# B:こんにちは！Aさん、元気ですか？
# --------------------
# B:こんにちは！Aさん、お元気ですか？
# --------------------
# B:こんにちは！Aさん！最近どうしてる？

# %%
# メッセージの設定
message = "言語モデルを使う上でのポイントは"

# APIへリクエスト
stream = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ],
    stream=True,
)

for chunk in stream:
    if chunk.choices:
        if chunk.choices[0].delta.content is not None:
            print(chunk.choices[0].delta.content, end="")
# Out:
# 言語モデルを効果的に使うためのポイントはいくつかあります。以下にいくつか挙げてみます：
#
# 1. **明確な指示を出す**: モデルに対して具体的で明確な質問やリクエストを行うことで、より適切な応答を得やすくなります。
#
# 2. **コンテキストを提供する**: 背景情報や関連するコンテキストを提供することで、モデルがより的確な回答を生成しやすくなります。
#
# 3. **フォーマットの指定**: 必要な情報を特定の形式で返してほしい場合、例えばリストや段落など、フォーマットを指定することが有効です。
#
# 4. **フィードバックを行う**: モデルの応答に対してフィードバックを与えることで、次第により好みのスタイルや内容に調整していくことができます。
#
# 5. **反復的な利用**: 複雑な問題の場合、一度で解決しようとせずに、段階的に質問を進めたり、追加情報を求めたりすることが役立ちます。
#
# 6. **セキュリティとプライバシーの考慮**: 個人情報や機密情報を含まないように注意し、プライバシーを守ることが重要です。
#
# 7. **バイアスに注意**: モデルは訓練データに基づいて生成されるため、バイアスや不正確な情報が含まれる可能性があります。情報の正確性を確認する習慣を持つことが大切です。
#
# 8. **用途を考慮する**: モデルの強みや弱みを理解し、適切な用途で活用することが望ましいです。例えば、創造的な文章生成やアイデア出しに向いていますが、完全な事実確認には向いていないことがあります。
#
# これらのポイントを意識することで、言語モデルをより効果的に活用できるでしょう。
